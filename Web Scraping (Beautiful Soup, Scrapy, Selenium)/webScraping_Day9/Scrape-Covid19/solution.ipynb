# %%
import requests
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
url="https://www.nepia.com/publications/covid-19-coronavirus-outbreak-impact-on-shipping/"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
html_data=soup(response.content)

# %%
country_data=html_data.findAll("div",{"class":"js-publications-page"})[2:]

# %%
countries=[]
info_party=[]
dates=[]
summary=[]
for country in country_data:
    countries.append(country.h1.text)
    info_party.append(country.findAll("td")[1].text)
    dates.append(country.find_all("td")[3].text)
    summary.append(country.find_all("td")[5].text)

# %%
countries
# Out:
# ['Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Aruba',
#  'Australia',
#  'Azores',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bonaire',
#  'Brazil',
#  'Bulgaria',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Canary Island',
#  'Cape Verde',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo (Democratic Republic of)',
#  'Congo (Republic of)',
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Estonia',
#  'Fiji',
#  'Finland',
#  'France',
#  'French Guyana',
#  'French Polynesia',
#  'Gabon',
#  'Gambia (The)',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Grenada',
#  'Guadeloupe',
#  'Guatemala',
#  'Guinea',
#  'Guinea Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland (Republic of)',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea',
#  'Kuwait',
#  'Latvia',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Madagascar',
#  'Malaysia',
#  'Malta',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Nigeria',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Papua New Guinea',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Qatar',
#  'Reunion Island',
#  'Romania',
#  'Russia',
#  'Saudi Arabia',
#  'Senegal',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovenia',
#  'Somaliland',
#  'South Africa',
#  'Spain',
#  'Sri Lanka',
#  'St Eustatius',
#  'St Lucia',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Syria',
#  'Taiwan',
#  'Tanzania',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Uruguay',
#  'USA - California',
#  'USA - Delaware Bay',
#  'USA - Federal (All States)',
#  'USA - Florida',
#  'USA - Georgia',
#  'USA - Hawaii',
#  'USA - Louisiana',
#  'USA - Maine',
#  'USA - New York',
#  'USA - North Carolina',
#  'USA - Texas',
#  'USA - Virginia',
#  'Venezuela',
#  'Vietnam',
#  'Yemen']

# %%
df=pd.DataFrame()

# %%
df["country"]=countries
df["Informing Party"]=info_party
df["Date"]=dates
df["Summary"]=summary

# %%
df.head(10)
# Out:
#       country                                    Informing Party      Date  \
# 0     Albania                                       Samer & Misa    27-May
# 1     Algeria  Neffous Shipping & Consulting (P&I)\nBemi P&I\...    15-May
# 2      Angola  GAC Angola\nETIC SAS\nAFRICA  P&I  Services\nB...     5-May
# 3   Argentina  Pandi Liquidadores S.R.L\nMarine Risk & Insura...    6-July
# 4       Aruba                      Caribbean Marine\nCariconsult   17-July
# 5   Australia  Aus Ship P&I\nInchcape Shipping Services\nGAC\...   29-June
# 6      Azores                                    GAC\nWilhelmsen    12-May
# 7     Bahamas                 GAC\nCaribbean Marine\nCariconsult   17-July
# 8     Bahrain                                        GAC Bahrain     5-May
# 9  Bangladesh  JF (Bangladesh) Limited\nInterport Group\nCoas...  4-August
#
#                                              Summary
# 0  The country is undergoing a gradual opening, a...
# 1  27 February: The port of Annaba notified all l...
# 2  31 March: Budd Group advise that all ports rem...
# 3  5 May: ITL advise new restrictions are imposed...
# 4  Since March 21, 2020 the government of Aruba i...
# 5  The Australian Government has announced that a...
# 6  Despite the COVID-19 outbreak, ports of the Az...
# 7  25 March: The port of Freeport, Grand Bahama –...
# 8  The following information / documents to be pr...
# 9  23 March: IMO Circular Letter No. 4239 states ...
