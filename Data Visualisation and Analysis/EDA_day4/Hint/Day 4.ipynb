# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/shrutayyyy_/Desktop/movies .csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df = df[['budget','revenue','release_year','cast','genres','runtime','original_title','production_companies']]

# %%
df.head()
# Out:
#       budget     revenue  release_year  \
# 0  150000000  1513528810          2015
# 1  150000000   378436354          2015
# 2  110000000   295238201          2015
# 3  200000000  2068178225          2015
# 4  190000000  1506249360          2015
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                       genres  runtime  \
# 0  Action|Adventure|Science Fiction|Thriller      124
# 1  Action|Adventure|Science Fiction|Thriller      120
# 2         Adventure|Science Fiction|Thriller      119
# 3   Action|Adventure|Science Fiction|Fantasy      136
# 4                      Action|Crime|Thriller      137
#
#                  original_title  \
# 0                Jurassic World
# ...

# %%
df.shape
# Out:
# (10866, 8)

# %%
df = df[df['budget'] != 0]
df = df[df['revenue'] != 0]

# %%
df.dropna()
# Out:
#           budget     revenue  release_year  \
# 0      150000000  1513528810          2015
# 1      150000000   378436354          2015
# 2      110000000   295238201          2015
# 3      200000000  2068178225          2015
# 4      190000000  1506249360          2015
# ...          ...         ...           ...
# 10822    7500000    33736689          1966
# 10828    3000000    13000000          1966
# 10829    4653000     6000000          1966
# 10835   12000000    20000000          1966
# 10848    5115000    12000000          1966
#
#                                                     cast  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                  ...
# ...

# %%
df.shape
# Out:
# (3855, 8)

# %%
df_2000 = df[df['release_year'] >= 2000]
df_2000_and_2005 = df_2000[df_2000['release_year'] <= 2006]
df_2000_and_2005.head()
# Out:
#          budget    revenue  release_year  \
# 2633   93000000  871368364          2001
# 2634  125000000  976475550          2001
# 2635   15000000   20117339          2001
# 2636    6000000    1270522          2001
# 2637  115000000  562816256          2001
#
#                                                    cast  \
# 2633  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 2634  Daniel Radcliffe|Rupert Grint|Emma Watson|John...
# 2635  Naomi Watts|Laura Harring|Ann Miller|Dan Heday...
# 2636  Jake Gyllenhaal|Patrick Swayze|Drew Barrymore|...
# 2637  John Goodman|Billy Crystal|Mary Gibbs|Steve Bu...
#
#                                genres  runtime  \
# 2633         Adventure|Fantasy|Action      178
# 2634         Adventure|Fantasy|Family      152
# 2635           Thriller|Drama|Mystery      147
# 2636            Fantasy|Drama|Mystery      113
# 2637  Fantasy|Animation|Family|Comedy       92
#
#                                          original_title  \
# ...

# %%
df_2000_and_2005.shape
# Out:
# (954, 8)

# %%
no_of_words = 0
for i in range(df.shape[0]):
    words_list = df_2000_and_2005['original_title'].values[i].split(' ')
    no_of_words = no_of_words + len(words_list)
    
ans2 = no_of_words/df_2000_and_2005.shape[0]
ans2
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-82f03e035d10> in <module>
#       1 no_of_words = 0
#       2 for i in range(df.shape[0]):
# ----> 3     words_list = df_2000_and_2005['original_title'].values[i].split(' ')
#       4     no_of_words = no_of_words + len(words_list)
#       5
#
# IndexError: index 954 is out of bounds for axis 0 with size 954

# %% [markdown]
# As number of words in a title cannot be in decimals, we'll say average number of words in the movie titles between 2000 and 2005 are 3

# %%
vin_diesel_df = df[df['cast'].str.contains('Vin Diesel')]
emma_watson_df = df[df['cast'].str.contains('Emma Watson')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-1001281f67b0> in <module>
# ----> 1 vin_diesel_df = df[df['cast'].str.contains('Vin Diesel')]
#       2 emma_watson_df = df[df['cast'].str.contains('Emma Watson')]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2788
#    2789         # Do we have a (boolean) 1d indexer?
# -> 2790         if com.is_bool_indexer(key):
#    2791             return self._getitem_bool_array(key)
#    2792
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     134             if not lib.is_bool_array(key):
#     135                 if isna(key).any():
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ...

# %%
genres_and_count = {}
for i in range(vin_diesel_df.shape[0]):
    genres = vin_diesel_df['genres'].values[i].split('|')
    for genre in genres:
        try:
            count = genres_and_count[genre]
            genres_and_count[genre] = count + 1
        except:
            genres_and_count[genre] = 1
            
genres_and_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-ffa375a0ad8f> in <module>
#       1 genres_and_count = {}
# ----> 2 for i in range(vin_diesel_df.shape[0]):
#       3     genres = vin_diesel_df['genres'].values[i].split('|')
#       4     for genre in genres:
#       5         try:
#
# NameError: name 'vin_diesel_df' is not defined

# %% [markdown]
# As if we had a doubt Action would be Vin Diesel's Genre!

# %%
genres_and_count = {}
for i in range(emma_watson_df.shape[0]):
    genres = emma_watson_df['genres'].values[i].split('|')
    for genre in genres:
        try:
            count = genres_and_count[genre]
            genres_and_count[genre] = count + 1
        except:
            genres_and_count[genre] = 1
            
genres_and_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-f81306b669b8> in <module>
#       1 genres_and_count = {}
# ----> 2 for i in range(emma_watson_df.shape[0]):
#       3     genres = emma_watson_df['genres'].values[i].split('|')
#       4     for genre in genres:
#       5         try:
#
# NameError: name 'emma_watson_df' is not defined

# %% [markdown]
# Adventure is our beloved Hermione's most frequent genre!

# %%
new = df.sort_values(['revenue'])
new[:10]
# Out:
#          budget  revenue  release_year  \
# 5067    6000000        2          2003
# 8142    6000000        2          1995
# 3239     200000        3          2008
# 8523   15000000        5          1996
# 5162         10        5          2003
# 10307  25000000        6          1993
# 8226    6400000        6          1995
# 5852         10       11          2013
# 8235          6       11          1995
# 10777        11       11          1978
#
#                                                     cast  \
# 5067   Hayden Christensen|Peter Sarsgaard|ChloÃ« Sevi...
# 8142   Jason Lee|Jeremy London|Shannen Doherty|Claire...
# 3239   Neil Patrick Harris|Nathan Fillion|Felicia Day...
# 8523   Dennis Miller|Erika Eleniak|Angie Everhart|Joh...
# 5162   Clayton Watson|Keanu Reeves|Carrie-Anne Moss|K...
# 10307  Meryl Streep|Glenn Close|Jeremy Irons|Winona R...
# 8226   Rebecca De Mornay|Antonio Banderas|Dennis Mill...
# 5852   Ingvar Eggert SigurÃ°sson|Charlotte BÃ¸ving|St...
# ...

# %%
production_comapnies = {}
for i in range(new.shape[0]):
    production_companies = new['production_companies'].values[i].split('|')
    for company in production_companies:
        try:
            count = production_comapnies[company]
            production_comapniesproduction_comapnies[company] = count + 1
        except:
            production_comapnies[company] = 1
            
production_comapnies
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-253e63fa5772> in <module>
#       1 production_comapnies = {}
#       2 for i in range(new.shape[0]):
# ----> 3     production_companies = new['production_companies'].values[i].split('|')
#       4     for company in production_companies:
#       5         try:
#
# AttributeError: 'float' object has no attribute 'split'

# %% [markdown]
# And here we have the production houses with the worst movies produced!
